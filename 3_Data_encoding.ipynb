# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
df = pd.read_csv('/content/fictional_character_battles_complex.csv')
df
# Out:
#          Character   Universe  Strength  Speed  Intelligence SpecialAbilities  \
# 0     Wonder Woman     Marvel         7      8             3      Telekinesis
# 1         Iron Man     Marvel         4      7             9      Telekinesis
# 2         Iron Man  DC Comics         8      7             5      Telekinesis
# 3       Spider-Man  DC Comics         5      6            10      Telekinesis
# 4            Flash     Marvel         7      6             2     Invisibility
# ...            ...        ...       ...    ...           ...              ...
# 2346      Superman  DC Comics         9      8             5   Super Strength
# 2347      Superman  DC Comics         2      5             8   Super Strength
# 2348         Flash  DC Comics         5      3             3      Telekinesis
# 2349        Batman  DC Comics         5     10             6           Flight
# 2350    Spider-Man     Marvel         8      1             5   Super Strength
#
# ...

# %%
# lets starts encoding the data

# %%
# what is encoding
# encoding is a process of converting a variable into a number

# %%
# Type of encoding
# 1. Label encoding
# 2. One-hot encoding
# 3. Ordinal encoding
# 4. Binary encoding
# 5. count encoding
# 6. Target encoding

# %%
# one-hot encoding
# How it works

# we have to perform one-hot encoding for universes

from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder()

df_universe = pd.DataFrame(onehotencoder.fit_transform(df[['Universe']]).toarray())
df_universe
# Out:
#         0    1
# 0     0.0  1.0
# 1     0.0  1.0
# 2     1.0  0.0
# 3     1.0  0.0
# 4     0.0  1.0
# ...   ...  ...
# 2346  1.0  0.0
# 2347  1.0  0.0
# 2348  1.0  0.0
# 2349  1.0  0.0
# 2350  0.0  1.0
#
# [2351 rows x 2 columns]

# %%
df.head()
# Out:
#       Character   Universe  Strength  Speed  Intelligence SpecialAbilities  \
# 0  Wonder Woman     Marvel         7      8             3      Telekinesis
# 1      Iron Man     Marvel         4      7             9      Telekinesis
# 2      Iron Man  DC Comics         8      7             5      Telekinesis
# 3    Spider-Man  DC Comics         5      6            10      Telekinesis
# 4         Flash     Marvel         7      6             2     Invisibility
#
#    Weaknesses  BattleOutcome
# 0  Kryptonite              0
# 1  Kryptonite              0
# 2       Magic              0
# 3  Kryptonite              0
# 4       Magic              0

# %%
# Dummy encoding
# How it works
# it removes last 1 columns

# we have to perform dummy encoding for SpecialAbilities

# use 0 and 1 not true or false

special_abilities = pd.get_dummies(df['SpecialAbilities'])
special_abilities
# Out:
#       Flight  Invisibility  Super Strength  Telekinesis
# 0      False         False           False         True
# 1      False         False           False         True
# 2      False         False           False         True
# 3      False         False           False         True
# 4      False          True           False        False
# ...      ...           ...             ...          ...
# 2346   False         False            True        False
# 2347   False         False            True        False
# 2348   False         False           False         True
# 2349    True         False           False        False
# 2350   False         False            True        False
#
# [2351 rows x 4 columns]

# %%
df.head()
# Out:
#       Character   Universe  Strength  Speed  Intelligence SpecialAbilities  \
# 0  Wonder Woman     Marvel         7      8             3      Telekinesis
# 1      Iron Man     Marvel         4      7             9      Telekinesis
# 2      Iron Man  DC Comics         8      7             5      Telekinesis
# 3    Spider-Man  DC Comics         5      6            10      Telekinesis
# 4         Flash     Marvel         7      6             2     Invisibility
#
#    Weaknesses  BattleOutcome
# 0  Kryptonite              0
# 1  Kryptonite              0
# 2       Magic              0
# 3  Kryptonite              0
# 4       Magic              0

# %%
# label encoding

from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

df_weakness = pd.DataFrame(labelencoder.fit_transform(df['Weaknesses']))
df_weakness
# Out:
#       0
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# ...  ..
# 2346  0
# 2347  1
# 2348  3
# 2349  3
# 2350  1
#
# [2351 rows x 1 columns]

# %%
df.head()
# Out:
#       Character   Universe  Strength  Speed  Intelligence SpecialAbilities  \
# 0  Wonder Woman     Marvel         7      8             3      Telekinesis
# 1      Iron Man     Marvel         4      7             9      Telekinesis
# 2      Iron Man  DC Comics         8      7             5      Telekinesis
# 3    Spider-Man  DC Comics         5      6            10      Telekinesis
# 4         Flash     Marvel         7      6             2     Invisibility
#
#    Weaknesses  BattleOutcome
# 0  Kryptonite              0
# 1  Kryptonite              0
# 2       Magic              0
# 3  Kryptonite              0
# 4       Magic              0

# %%
# ordinal encoding

from sklearn.preprocessing import OrdinalEncoder
ordinalencoder = OrdinalEncoder()

df_universe = pd.DataFrame(ordinalencoder.fit_transform(df[['Universe']]))
df_universe
# Out:
#         0
# 0     1.0
# 1     1.0
# 2     0.0
# 3     0.0
# 4     1.0
# ...   ...
# 2346  0.0
# 2347  0.0
# 2348  0.0
# 2349  0.0
# 2350  1.0
#
# [2351 rows x 1 columns]

# %%
# Binary encoding

from sklearn.preprocessing import Binarizer
binarizer = Binarizer(threshold = 5)

df_strength = pd.DataFrame(binarizer.fit_transform(df[['Strength']]))
df_strength
# Out:
#       0
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# ...  ..
# 2346  1
# 2347  0
# 2348  0
# 2349  0
# 2350  1
#
# [2351 rows x 1 columns]

# %%
# count encoding

from sklearn.preprocessing import CountEncoder
countencoder = CountEncoder()

df_universe = pd.DataFrame(countencoder.fit_transform(df[['Universe']]))
df_universe
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-2b07017ff5ec> in <cell line: 3>()
#       1 # count encoding
#       2
# ----> 3 from sklearn.preprocessing import CountEncoder
#       4 countencoder = CountEncoder()
#       5
#
# ImportError: cannot import name 'CountEncoder' from 'sklearn.preprocessing' (/usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install --upgrade scikit-learn

# %%
# mean encoding

from sklearn.preprocessing import MeanEncoder
meanencoder = MeanEncoder()

df_universe = pd.DataFrame(meanencoder.fit_transform(df[['Universe']]))
df_universe
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-18201e9242f0> in <cell line: 3>()
#       1 # mean encoding
#       2
# ----> 3 from sklearn.preprocessing import MeanEncoder
#       4 meanencoder = MeanEncoder()
#       5
#
# ImportError: cannot import name 'MeanEncoder' from 'sklearn.preprocessing' (/usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
